# %% [markdown]
# # ENRON fraud detection
# Identify persons of interest (POIs) from ENRON financial and email data (educational purpose)

# %%
# Import some modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import sys
import pickle

sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

# %%
# Path to images and data
IMAGES = '../images/'
DATA   = '../data/'

# %%
### Task 1: Select what features you'll use.
### features_list is a list of strings, each of which is a feature name.
### The first feature must be "poi".

#features_list = ['poi','salary'] # You will need to use more features

# %%
### Load the dictionary containing the dataset
with open("../data/final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

# %%
#data_dict

# %%
columns = ['poi',
           'salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments', 
           'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value',
           'email_address', 'to_messages', 'from_messages', 'from_this_person_to_poi', 'from_poi_to_this_person', 'shared_receipt_with_poi']

# %%
data_Frame = pd.DataFrame(data_dict).transpose()
data_Frame = data_Frame[ columns ]

# %%
# Replace 'NaN' string with numpy.NaN
# Change POI from boolean to integer (poi: 1, no_poi: 0)
def repl_NaN(val):
    if val == 'NaN':
        val = np.NaN
    if isinstance(val, bool):
        val = int(val)
    return val

data_Frame = data_Frame.applymap(repl_NaN)

# %%
data_Frame.head()
# Out:
#                     poi    salary      bonus  long_term_incentive  \
# ALLEN PHILLIP K       0  201955.0  4175000.0             304805.0
# BADUM JAMES P         0       NaN        NaN                  NaN
# BANNANTINE JAMES M    0     477.0        NaN                  NaN
# BAXTER JOHN C         0  267102.0  1200000.0            1586055.0
# BAY FRANKLIN R        0  239671.0   400000.0                  NaN
#
#                     deferred_income  deferral_payments  loan_advances  \
# ALLEN PHILLIP K          -3081055.0          2869717.0            NaN
# BADUM JAMES P                   NaN           178980.0            NaN
# BANNANTINE JAMES M          -5104.0                NaN            NaN
# BAXTER JOHN C            -1386055.0          1295738.0            NaN
# BAY FRANKLIN R            -201641.0           260455.0            NaN
#
#                         other  expenses  director_fees  ...  \
# ALLEN PHILLIP K         152.0   13868.0            NaN  ...
# BADUM JAMES P             NaN    3486.0            NaN  ...
# BANNANTINE JAMES M   864523.0   56301.0            NaN  ...
# BAXTER JOHN C       2660303.0   11200.0            NaN  ...
# BAY FRANKLIN R           69.0  129142.0            NaN  ...
#
#                     exercised_stock_options  restricted_stock  \
# ALLEN PHILLIP K                   1729541.0          126027.0
# BADUM JAMES P                      257817.0               NaN
# BANNANTINE JAMES M                4046157.0         1757552.0
# BAXTER JOHN C                     6680544.0         3942714.0
# BAY FRANKLIN R                          NaN          145796.0
#
#                     restricted_stock_deferred  total_stock_value  \
# ALLEN PHILLIP K                     -126027.0          1729541.0
# BADUM JAMES P                             NaN           257817.0
# BANNANTINE JAMES M                  -560222.0          5243487.0
# BAXTER JOHN C                             NaN         10623258.0
# BAY FRANKLIN R                       -82782.0            63014.0
#
#                                  email_address to_messages  from_messages  \
# ALLEN PHILLIP K        phillip.allen@enron.com      2902.0         2195.0
# BADUM JAMES P                              NaN         NaN            NaN
# BANNANTINE JAMES M  james.bannantine@enron.com       566.0           29.0
# BAXTER JOHN C                              NaN         NaN            NaN
# BAY FRANKLIN R             frank.bay@enron.com         NaN            NaN
#
#                     from_this_person_to_poi  from_poi_to_this_person  \
# ALLEN PHILLIP K                        65.0                     47.0
# BADUM JAMES P                           NaN                      NaN
# BANNANTINE JAMES M                      0.0                     39.0
# BAXTER JOHN C                           NaN                      NaN
# BAY FRANKLIN R                          NaN                      NaN
#
#                     shared_receipt_with_poi
# ALLEN PHILLIP K                      1407.0
# BADUM JAMES P                           NaN
# BANNANTINE JAMES M                    465.0
# BAXTER JOHN C                           NaN
# BAY FRANKLIN R                          NaN
#
# [5 rows x 21 columns]

# %%
data_Frame.describe().transpose()
# Out:
#                            count          mean           std         min  \
# poi                        146.0  1.232877e-01  3.298989e-01         0.0
# salary                      95.0  5.621943e+05  2.716369e+06       477.0
# bonus                       82.0  2.374235e+06  1.071333e+07     70000.0
# long_term_incentive         66.0  1.470361e+06  5.942759e+06     69223.0
# deferred_income             49.0 -1.140475e+06  4.025406e+06 -27992891.0
# deferral_payments           39.0  1.642674e+06  5.161930e+06   -102500.0
# loan_advances                4.0  4.196250e+07  4.708321e+07    400000.0
# other                       93.0  9.190650e+05  4.589253e+06         2.0
# expenses                    95.0  1.087289e+05  5.335348e+05       148.0
# director_fees               17.0  1.668049e+05  3.198914e+05      3285.0
# total_payments             125.0  5.081526e+06  2.906172e+07       148.0
# exercised_stock_options    102.0  5.987054e+06  3.106201e+07      3285.0
# restricted_stock           110.0  2.321741e+06  1.251828e+07  -2604490.0
# restricted_stock_deferred   18.0  1.664106e+05  4.201494e+06  -7576788.0
# total_stock_value          126.0  6.773957e+06  3.895777e+07    -44093.0
# to_messages                 86.0  2.073860e+03  2.582701e+03        57.0
# from_messages               86.0  6.087907e+02  1.841034e+03        12.0
# from_this_person_to_poi     86.0  4.123256e+01  1.000731e+02         0.0
# from_poi_to_this_person     86.0  6.489535e+01  8.697924e+01         0.0
# shared_receipt_with_poi     86.0  1.176465e+03  1.178318e+03         2.0
#
#                                   25%         50%          75%          max
# poi                              0.00         0.0         0.00          1.0
# salary                      211816.00    259996.0    312117.00   26704229.0
# bonus                       431250.00    769375.0   1200000.00   97343619.0
# long_term_incentive         281250.00    442035.0    938672.00   48521928.0
# deferred_income            -694862.00   -159792.0    -38346.00       -833.0
# deferral_payments            81573.00    227449.0   1002671.50   32083396.0
# loan_advances              1600000.00  41762500.0  82125000.00   83925000.0
# other                         1215.00     52382.0    362096.00   42667589.0
# expenses                     22614.00     46950.0     79952.50    5235198.0
# director_fees                98784.00    108579.0    113784.00    1398517.0
# total_payments              394475.00   1101393.0   2093263.00  309886585.0
# exercised_stock_options     527886.25   1310813.5   2547724.00  311764000.0
# restricted_stock            254018.00    451740.0   1002369.75  130322299.0
# restricted_stock_deferred  -389621.75   -146975.0    -75009.75   15456290.0
# total_stock_value           494510.25   1102872.5   2949846.75  434509511.0
# to_messages                    541.25      1211.0      2634.75      15149.0
# from_messages                   22.75        41.0       145.50      14368.0
# from_this_person_to_poi          1.00         8.0        24.75        609.0
# from_poi_to_this_person         10.00        35.0        72.25        528.0
# shared_receipt_with_poi        249.75       740.5      1888.25       5521.0

# %%
data_Frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146 entries, ALLEN PHILLIP K to YEAP SOON
# Data columns (total 21 columns):
# poi                          146 non-null int64
# salary                       95 non-null float64
# bonus                        82 non-null float64
# long_term_incentive          66 non-null float64
# deferred_income              49 non-null float64
# deferral_payments            39 non-null float64
# loan_advances                4 non-null float64
# other                        93 non-null float64
# expenses                     95 non-null float64
# director_fees                17 non-null float64
# total_payments               125 non-null float64
# exercised_stock_options      102 non-null float64
# restricted_stock             110 non-null float64
# restricted_stock_deferred    18 non-null float64
# total_stock_value            126 non-null float64
# email_address                111 non-null object
# to_messages                  86 non-null float64
# from_messages                86 non-null float64
# from_this_person_to_poi      86 non-null float64
# from_poi_to_this_person      86 non-null float64
# shared_receipt_with_poi      86 non-null float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 25.1+ KB

# %%
feature_list = data_Frame.columns.to_list()
feature_list.remove('poi')
feature_list.remove('email_address')

# %%
feature_list
# Out:
# ['salary',
#  'bonus',
#  'long_term_incentive',
#  'deferred_income',
#  'deferral_payments',
#  'loan_advances',
#  'other',
#  'expenses',
#  'director_fees',
#  'total_payments',
#  'exercised_stock_options',
#  'restricted_stock',
#  'restricted_stock_deferred',
#  'total_stock_value',
#  'to_messages',
#  'from_messages',
#  'from_this_person_to_poi',
#  'from_poi_to_this_person',
#  'shared_receipt_with_poi']

# %%
payment_features = ['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments']
stock_features   = ['exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value']
mail_features    = ['to_messages', 'from_messages', 'from_this_person_to_poi', 'from_poi_to_this_person', 'shared_receipt_with_poi']

# %%
data_Frame.loc[ ['THE TRAVEL AGENCY IN THE PARK', 'TOTAL'] ].transpose()
# Out:
#                           THE TRAVEL AGENCY IN THE PARK        TOTAL
# poi                                                   0            0
# salary                                              NaN  2.67042e+07
# bonus                                               NaN  9.73436e+07
# long_term_incentive                                 NaN  4.85219e+07
# deferred_income                                     NaN -2.79929e+07
# deferral_payments                                   NaN  3.20834e+07
# loan_advances                                       NaN   8.3925e+07
# other                                            362096  4.26676e+07
# expenses                                            NaN   5.2352e+06
# director_fees                                       NaN  1.39852e+06
# total_payments                                   362096  3.09887e+08
# exercised_stock_options                             NaN  3.11764e+08
# restricted_stock                                    NaN  1.30322e+08
# restricted_stock_deferred                           NaN -7.57679e+06
# total_stock_value                                   NaN   4.3451e+08
# email_address                                       NaN          NaN
# to_messages                                         NaN          NaN
# from_messages                                       NaN          NaN
# from_this_person_to_poi                             NaN          NaN
# from_poi_to_this_person                             NaN          NaN
# shared_receipt_with_poi                             NaN          NaN

# %%
data_Frame.to_latex()
# Out:
# u'\\begin{tabular}{lrrrrrrrrrrrrrrrlrrrrr}\n\\toprule\n{} &  poi &      salary &       bonus &  long\\_term\\_incentive &  deferred\\_income &  deferral\\_payments &  loan\\_advances &       other &   expenses &  director\\_fees &  total\\_payments &  exercised\\_stock\\_options &  restricted\\_stock &  restricted\\_stock\\_deferred &  total\\_stock\\_value &                     email\\_address &  to\\_messages &  from\\_messages &  from\\_this\\_person\\_to\\_poi &  from\\_poi\\_to\\_this\\_person &  shared\\_receipt\\_with\\_poi \\\\\n\\midrule\nALLEN PHILLIP K               &    0 &    201955.0 &   4175000.0 &             304805.0 &       -3081055.0 &          2869717.0 &            NaN &       152.0 &    13868.0 &            NaN &       4484442.0 &                1729541.0 &          126027.0 &                  -126027.0 &          1729541.0 &           phillip.allen@enron.com &       2902.0 &         2195.0 &                     65.0 &                     47.0 &                   1407.0 \\\\\nBADUM JAMES P                 &    0 &         NaN &         NaN &                  NaN &              NaN &           178980.0 &            NaN &         NaN &     3486.0 &            NaN &        182466.0 &                 257817.0 &               NaN &                        NaN &           257817.0 &                               NaN &          NaN &            NaN &                      NaN &                      NaN &                      NaN \\\\\nBANNANTINE JAMES M            &    0 &       477.0 &         NaN &                  NaN &          -5104.0 &                NaN &            NaN &    864523.0 &    56301.0 &            NaN &        916197.0 &                4046157.0 &         1757552.0 &                  -560222.0 &          5243487.0 &        james.bannantine@enron.com &        566.0 &           29.0 &                      0.0 &                     39.0 &                    465.0 \\\\\nBAXTER JOHN C                 &    0 &    267102.0 &   1200000.0 &            1586055.0 &       -1386055.0 &          1295738.0 &            NaN &   2660303.0 &    11200.0 &            NaN &       5634343.0 &                6680544.0 &         3942714.0 &                        NaN &         10623258.0 &                               NaN &          NaN &            NaN &                      NaN &                      NaN &                      NaN \\\\\nBAY FRANKLIN R                &    0 &    239671.0 &    400000.0 &                  NaN &        -201641.0 &           260455.0 &            NaN &        69.0 &   129142.0 &            NaN &        827696.0 &                      NaN &          145796.0 &                   -82782.0 &            63014.0 &               frank.bay@enron.com &          NaN &            NaN &                      NaN &                      NaN &                      NaN \\\\\nBAZELIDES PHILIP J            &    0 &     80818.0 &         NaN &              93750.0 &              NaN &           684694.0 &            NaN &       874.0 &        NaN &            NaN &        860136.0 &                1599641.0 &               NaN &                        NaN &          1599641.0 &                               NaN &          NaN &            NaN &                      NaN &                      NaN &                      NaN \\\\\nBECK SALLY W                  &    0 &    231330.0 &    700000.0 &                  NaN &              NaN &                NaN &            NaN &       566.0 &    37172.0 &            NaN &        969068.0 &                      NaN &          126027.0 &                        NaN &           126027.0 &              sally.beck@enron.com &       7315.0 &         4343.0 &                    386.0 &                    144.0 &                   2639.0 \\\\\nBELDEN TIMOTHY N              &    1 &    213999.0 &   5249999.0 &                  NaN &       -2334434.0 &          2144013.0 &            NaN &    210698.0 &    17355.0 &            NaN &       5501630.0 &                 953136.0 ...

# %%
data_Frame[ data_Frame['bonus'] >= 10000000 ]
# Out:
#        poi      salary       bonus  long_term_incentive  deferred_income  \
# TOTAL    0  26704229.0  97343619.0           48521928.0      -27992891.0
#
#        deferral_payments  loan_advances       other   expenses  director_fees  \
# TOTAL         32083396.0     83925000.0  42667589.0  5235198.0      1398517.0
#
#        ...  exercised_stock_options  restricted_stock  \
# TOTAL  ...              311764000.0       130322299.0
#
#        restricted_stock_deferred  total_stock_value  email_address  \
# TOTAL                 -7576788.0        434509511.0            NaN
#
#       to_messages  from_messages  from_this_person_to_poi  \
# TOTAL         NaN            NaN                      NaN
#
#        from_poi_to_this_person  shared_receipt_with_poi
# TOTAL                      NaN                      NaN
#
# [1 rows x 21 columns]

# %%
# Dropping the 'TOTAL' instance
data_Frame.drop(labels='TOTAL', inplace=True)

# %%
data_Frame.loc['THE TRAVEL AGENCY IN THE PARK']
# Out:
# poi                               0
# salary                          NaN
# bonus                           NaN
# long_term_incentive             NaN
# deferred_income                 NaN
# deferral_payments               NaN
# loan_advances                   NaN
# other                        362096
# expenses                        NaN
# director_fees                   NaN
# total_payments               362096
# exercised_stock_options         NaN
# restricted_stock                NaN
# restricted_stock_deferred       NaN
# total_stock_value               NaN
# email_address                   NaN
# to_messages                     NaN
# from_messages                   NaN
# from_this_person_to_poi         NaN
# from_poi_to_this_person         NaN
# shared_receipt_with_poi         NaN
# Name: THE TRAVEL AGENCY IN THE PARK, dtype: object

# %%
# Drop 'THE TRAVEL AGENCY IN THE PARK' instance. This is an agency and not a real person. In addition there is not much data available for this instance.
data_Frame.drop(labels='THE TRAVEL AGENCY IN THE PARK', inplace=True)

# %%
insider = data_Frame.index.to_list()

# %%
data_Frame.hist(bins=20,figsize=(20,15));
plt.tight_layout()
plt.savefig(IMAGES+"features_histogram_plots", dpi='figure')
plt.show()

# %%
### Task 2: Remove outliers

# %%
def crt_plot(data, features, type='box', figsize=(20,15), shape=(1,1), log=[], bins=10, sort=True, color='orange', save=False):
    '''
    Creates multiple boxplots from dataframe and organizes plots in 2D matrix.
    ---
    data:        pandas data frame
    features:    list of column names of data frame to be plotted
    figsize:     tuple of width x hight
    shape:       tuple of rows x columns in fig
    log:         list of features with logarithmic y axis scale (only necessary when your data contains outlyers)
    sort:        boolean, if True features will be sorted
    color:       color string, see matplotlib docs for valid colors
    save:        filename as string or False
    
    Returns None
    '''
    rows = shape[0]
    cols = shape[1]
    fig, ax = plt.subplots(rows, cols, figsize=figsize)
    if sort == True:
        plot_iter = iter( sorted(features) )
    else:
        plot_iter = iter( features )
    for row in range(rows):
        for col in range(cols):
            column = next(plot_iter, 'STOP')
            if column == 'STOP':
                continue
            else:
                sns.boxplot(data=data[column], ax=ax[row,col], color=color)
                ax[row,col].set_title(column)
                if column in log:
                    ax[row,col].set_yscale('log')
    plt.tight_layout()
    if save is not False:
        plt.savefig(save, dpi='figure')
    plt.show()
    return None

# %%
log_list = ['from_messages', 'from_this_person_to_poi', 'total_payments', 'total_stock_value', 'other', 'restricted_stock', 'exercised_stock_options']
crt_plot(data_Frame, ['poi'] + feature_list, shape=(5,4), log=log_list, save=IMAGES+"features_box_plots", sort=False)

# %%
# Checked, OK
data_Frame[ data_Frame['salary'] >= 1000000 ]
# Out:
#                     poi     salary      bonus  long_term_incentive  \
# FREVERT MARK A        0  1060932.0  2000000.0            1617011.0
# LAY KENNETH L         1  1072321.0  7000000.0            3600000.0
# SKILLING JEFFREY K    1  1111258.0  5600000.0            1920000.0
#
#                     deferred_income  deferral_payments  loan_advances  \
# FREVERT MARK A           -3367011.0          6426990.0      2000000.0
# LAY KENNETH L             -300000.0           202911.0     81525000.0
# SKILLING JEFFREY K              NaN                NaN            NaN
#
#                          other  expenses  director_fees  ...  \
# FREVERT MARK A       7427621.0   86987.0            NaN  ...
# LAY KENNETH L       10359729.0   99832.0            NaN  ...
# SKILLING JEFFREY K     22122.0   29336.0            NaN  ...
#
#                     exercised_stock_options  restricted_stock  \
# FREVERT MARK A                   10433518.0         4188667.0
# LAY KENNETH L                    34348384.0        14761694.0
# SKILLING JEFFREY K               19250000.0         6843672.0
#
#                     restricted_stock_deferred  total_stock_value  \
# FREVERT MARK A                            NaN         14622185.0
# LAY KENNETH L                             NaN         49110078.0
# SKILLING JEFFREY K                        NaN         26093672.0
#
#                               email_address to_messages  from_messages  \
# FREVERT MARK A       mark.frevert@enron.com      3275.0           21.0
# LAY KENNETH L         kenneth.lay@enron.com      4273.0           36.0
# SKILLING JEFFREY K  jeff.skilling@enron.com      3627.0          108.0
#
#                     from_this_person_to_poi  from_poi_to_this_person  \
# FREVERT MARK A                          6.0                    242.0
# LAY KENNETH L                          16.0                    123.0
# SKILLING JEFFREY K                     30.0                     88.0
#
#                     shared_receipt_with_poi
# FREVERT MARK A                       2979.0
# LAY KENNETH L                        2411.0
# SKILLING JEFFREY K                   2042.0
#
# [3 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['long_term_incentive'] >= 3000000 ]
# Out:
#                  poi     salary      bonus  long_term_incentive  \
# LAY KENNETH L      1  1072321.0  7000000.0            3600000.0
# MARTIN AMANDA K    0   349487.0        NaN            5145434.0
#
#                  deferred_income  deferral_payments  loan_advances  \
# LAY KENNETH L          -300000.0           202911.0     81525000.0
# MARTIN AMANDA K              NaN            85430.0            NaN
#
#                       other  expenses  director_fees  ...  \
# LAY KENNETH L    10359729.0   99832.0            NaN  ...
# MARTIN AMANDA K   2818454.0    8211.0            NaN  ...
#
#                  exercised_stock_options  restricted_stock  \
# LAY KENNETH L                 34348384.0        14761694.0
# MARTIN AMANDA K                2070306.0               NaN
#
#                  restricted_stock_deferred  total_stock_value  \
# LAY KENNETH L                          NaN         49110078.0
# MARTIN AMANDA K                        NaN          2070306.0
#
#                          email_address to_messages  from_messages  \
# LAY KENNETH L    kenneth.lay@enron.com      4273.0           36.0
# MARTIN AMANDA K    a..martin@enron.com      1522.0          230.0
#
#                  from_this_person_to_poi  from_poi_to_this_person  \
# LAY KENNETH L                       16.0                    123.0
# MARTIN AMANDA K                      0.0                      8.0
#
#                  shared_receipt_with_poi
# LAY KENNETH L                     2411.0
# MARTIN AMANDA K                    477.0
#
# [2 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['bonus'] >= 4000000 ]
# Out:
#                     poi     salary      bonus  long_term_incentive  \
# ALLEN PHILLIP K       0   201955.0  4175000.0             304805.0
# BELDEN TIMOTHY N      1   213999.0  5249999.0                  NaN
# LAVORATO JOHN J       0   339288.0  8000000.0            2035380.0
# LAY KENNETH L         1  1072321.0  7000000.0            3600000.0
# SKILLING JEFFREY K    1  1111258.0  5600000.0            1920000.0
#
#                     deferred_income  deferral_payments  loan_advances  \
# ALLEN PHILLIP K          -3081055.0          2869717.0            NaN
# BELDEN TIMOTHY N         -2334434.0          2144013.0            NaN
# LAVORATO JOHN J                 NaN                NaN            NaN
# LAY KENNETH L             -300000.0           202911.0     81525000.0
# SKILLING JEFFREY K              NaN                NaN            NaN
#
#                          other  expenses  director_fees  ...  \
# ALLEN PHILLIP K          152.0   13868.0            NaN  ...
# BELDEN TIMOTHY N      210698.0   17355.0            NaN  ...
# LAVORATO JOHN J         1552.0   49537.0            NaN  ...
# LAY KENNETH L       10359729.0   99832.0            NaN  ...
# SKILLING JEFFREY K     22122.0   29336.0            NaN  ...
#
#                     exercised_stock_options  restricted_stock  \
# ALLEN PHILLIP K                   1729541.0          126027.0
# BELDEN TIMOTHY N                   953136.0          157569.0
# LAVORATO JOHN J                   4158995.0         1008149.0
# LAY KENNETH L                    34348384.0        14761694.0
# SKILLING JEFFREY K               19250000.0         6843672.0
#
#                     restricted_stock_deferred  total_stock_value  \
# ALLEN PHILLIP K                     -126027.0          1729541.0
# BELDEN TIMOTHY N                          NaN          1110705.0
# LAVORATO JOHN J                           NaN          5167144.0
# LAY KENNETH L                             NaN         49110078.0
# SKILLING JEFFREY K                        NaN         26093672.0
#
#                               email_address to_messages  from_messages  \
# ALLEN PHILLIP K     phillip.allen@enron.com      2902.0         2195.0
# BELDEN TIMOTHY N       tim.belden@enron.com      7991.0          484.0
# LAVORATO JOHN J     john.lavorato@enron.com      7259.0         2585.0
# LAY KENNETH L         kenneth.lay@enron.com      4273.0           36.0
# SKILLING JEFFREY K  jeff.skilling@enron.com      3627.0          108.0
#
#                     from_this_person_to_poi  from_poi_to_this_person  \
# ALLEN PHILLIP K                        65.0                     47.0
# BELDEN TIMOTHY N                      108.0                    228.0
# LAVORATO JOHN J                       411.0                    528.0
# LAY KENNETH L                          16.0                    123.0
# SKILLING JEFFREY K                     30.0                     88.0
#
#                     shared_receipt_with_poi
# ALLEN PHILLIP K                      1407.0
# BELDEN TIMOTHY N                     5521.0
# LAVORATO JOHN J                      3962.0
# LAY KENNETH L                        2411.0
# SKILLING JEFFREY K                   2042.0
#
# [5 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['deferral_payments'] >= 3000000 ]
# Out:
#                   poi     salary      bonus  long_term_incentive  \
# FREVERT MARK A      0  1060932.0  2000000.0            1617011.0
# HORTON STANLEY C    0        NaN        NaN                  NaN
#
#                   deferred_income  deferral_payments  loan_advances  \
# FREVERT MARK A         -3367011.0          6426990.0      2000000.0
# HORTON STANLEY C              NaN          3131860.0            NaN
#
#                       other  expenses  director_fees  ...  \
# FREVERT MARK A    7427621.0   86987.0            NaN  ...
# HORTON STANLEY C        NaN       NaN            NaN  ...
#
#                   exercised_stock_options  restricted_stock  \
# FREVERT MARK A                 10433518.0         4188667.0
# HORTON STANLEY C                5210569.0         2046079.0
#
#                   restricted_stock_deferred  total_stock_value  \
# FREVERT MARK A                          NaN         14622185.0
# HORTON STANLEY C                        NaN          7256648.0
#
#                              email_address to_messages  from_messages  \
# FREVERT MARK A      mark.frevert@enron.com      3275.0           21.0
# HORTON STANLEY C  stanley.horton@enron.com      2350.0         1073.0
#
#                   from_this_person_to_poi  from_poi_to_this_person  \
# FREVERT MARK A                        6.0                    242.0
# HORTON STANLEY C                     15.0                     44.0
#
#                   shared_receipt_with_poi
# FREVERT MARK A                     2979.0
# HORTON STANLEY C                   1074.0
#
# [2 rows x 21 columns]

# %%
data_Frame.loc['HORTON STANLEY C']
# Out:
# poi                                                 0
# salary                                            NaN
# bonus                                             NaN
# long_term_incentive                               NaN
# deferred_income                                   NaN
# deferral_payments                         3.13186e+06
# loan_advances                                     NaN
# other                                             NaN
# expenses                                          NaN
# director_fees                                     NaN
# total_payments                            3.13186e+06
# exercised_stock_options                   5.21057e+06
# restricted_stock                          2.04608e+06
# restricted_stock_deferred                         NaN
# total_stock_value                         7.25665e+06
# email_address                stanley.horton@enron.com
# to_messages                                      2350
# from_messages                                    1073
# from_this_person_to_poi                            15
# from_poi_to_this_person                            44
# shared_receipt_with_poi                          1074
# Name: HORTON STANLEY C, dtype: object

# %%
# Checked, OK
data_Frame[ data_Frame['other'] >= 3000000 ]
# Out:
#                 poi     salary      bonus  long_term_incentive  \
# FREVERT MARK A    0  1060932.0  2000000.0            1617011.0
# LAY KENNETH L     1  1072321.0  7000000.0            3600000.0
#
#                 deferred_income  deferral_payments  loan_advances       other  \
# FREVERT MARK A       -3367011.0          6426990.0      2000000.0   7427621.0
# LAY KENNETH L         -300000.0           202911.0     81525000.0  10359729.0
#
#                 expenses  director_fees  ...  exercised_stock_options  \
# FREVERT MARK A   86987.0            NaN  ...               10433518.0
# LAY KENNETH L    99832.0            NaN  ...               34348384.0
#
#                 restricted_stock  restricted_stock_deferred  \
# FREVERT MARK A         4188667.0                        NaN
# LAY KENNETH L         14761694.0                        NaN
#
#                 total_stock_value           email_address to_messages  \
# FREVERT MARK A         14622185.0  mark.frevert@enron.com      3275.0
# LAY KENNETH L          49110078.0   kenneth.lay@enron.com      4273.0
#
#                 from_messages  from_this_person_to_poi  \
# FREVERT MARK A           21.0                      6.0
# LAY KENNETH L            36.0                     16.0
#
#                 from_poi_to_this_person  shared_receipt_with_poi
# FREVERT MARK A                    242.0                   2979.0
# LAY KENNETH L                     123.0                   2411.0
#
# [2 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['expenses'] >= 200000 ]
# Out:
#                   poi    salary     bonus  long_term_incentive  \
# MCCLELLAN GEORGE    0  263413.0  900000.0                  NaN
# URQUHART JOHN A     0       NaN       NaN                  NaN
#
#                   deferred_income  deferral_payments  loan_advances    other  \
# MCCLELLAN GEORGE        -125000.0                NaN            NaN  51587.0
# URQUHART JOHN A          -36666.0                NaN            NaN      NaN
#
#                   expenses  director_fees  ...  exercised_stock_options  \
# MCCLELLAN GEORGE  228763.0            NaN  ...                 506765.0
# URQUHART JOHN A   228656.0        36666.0  ...                      NaN
#
#                   restricted_stock  restricted_stock_deferred  \
# MCCLELLAN GEORGE          441096.0                        NaN
# URQUHART JOHN A                NaN                        NaN
#
#                   total_stock_value               email_address to_messages  \
# MCCLELLAN GEORGE           947861.0  george.mcclellan@enron.com      1744.0
# URQUHART JOHN A                 NaN                         NaN         NaN
#
#                   from_messages  from_this_person_to_poi  \
# MCCLELLAN GEORGE           49.0                      0.0
# URQUHART JOHN A             NaN                      NaN
#
#                   from_poi_to_this_person  shared_receipt_with_poi
# MCCLELLAN GEORGE                     52.0                   1469.0
# URQUHART JOHN A                       NaN                      NaN
#
# [2 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['director_fees'] <= 100000 ]
# Out:
#                  poi  salary  bonus  long_term_incentive  deferred_income  \
# BELFER ROBERT      0     NaN    NaN                  NaN              NaN
# CHAN RONNIE        0     NaN    NaN                  NaN         -98784.0
# MEYER JEROME J     0     NaN    NaN                  NaN         -38346.0
# POWERS WILLIAM     0     NaN    NaN                  NaN         -17500.0
# URQUHART JOHN A    0     NaN    NaN                  NaN         -36666.0
#
#                  deferral_payments  loan_advances  other  expenses  \
# BELFER ROBERT            -102500.0            NaN    NaN       NaN
# CHAN RONNIE                    NaN            NaN    NaN       NaN
# MEYER JEROME J                 NaN            NaN    NaN    2151.0
# POWERS WILLIAM                 NaN            NaN    NaN       NaN
# URQUHART JOHN A                NaN            NaN    NaN  228656.0
#
#                  director_fees  ...  exercised_stock_options  \
# BELFER ROBERT           3285.0  ...                   3285.0
# CHAN RONNIE            98784.0  ...                      NaN
# MEYER JEROME J         38346.0  ...                      NaN
# POWERS WILLIAM         17500.0  ...                      NaN
# URQUHART JOHN A        36666.0  ...                      NaN
#
#                  restricted_stock  restricted_stock_deferred  \
# BELFER ROBERT                 NaN                    44093.0
# CHAN RONNIE               32460.0                   -32460.0
# MEYER JEROME J                NaN                        NaN
# POWERS WILLIAM                NaN                        NaN
# URQUHART JOHN A               NaN                        NaN
#
#                  total_stock_value         email_address to_messages  \
# BELFER ROBERT             -44093.0                   NaN         NaN
# CHAN RONNIE                    NaN                   NaN         NaN
# MEYER JEROME J                 NaN                   NaN         NaN
# POWERS WILLIAM                 NaN  ken.powers@enron.com       653.0
# URQUHART JOHN A                NaN                   NaN         NaN
#
#                  from_messages  from_this_person_to_poi  \
# BELFER ROBERT              NaN                      NaN
# CHAN RONNIE                NaN                      NaN
# MEYER JEROME J             NaN                      NaN
# POWERS WILLIAM            26.0                      0.0
# URQUHART JOHN A            NaN                      NaN
#
#                  from_poi_to_this_person  shared_receipt_with_poi
# BELFER ROBERT                        NaN                      NaN
# CHAN RONNIE                          NaN                      NaN
# MEYER JEROME J                       NaN                      NaN
# POWERS WILLIAM                       0.0                     12.0
# URQUHART JOHN A                      NaN                      NaN
#
# [5 rows x 21 columns]

# %%
# Checked. OK
data_Frame[ data_Frame['exercised_stock_options'] >= 15000000 ]
# Out:
#                     poi     salary      bonus  long_term_incentive  \
# HIRKO JOSEPH          1        NaN        NaN                  NaN
# LAY KENNETH L         1  1072321.0  7000000.0            3600000.0
# PAI LOU L             0   261879.0  1000000.0                  NaN
# RICE KENNETH D        1   420636.0  1750000.0            1617011.0
# SKILLING JEFFREY K    1  1111258.0  5600000.0            1920000.0
#
#                     deferred_income  deferral_payments  loan_advances  \
# HIRKO JOSEPH                    NaN            10259.0            NaN
# LAY KENNETH L             -300000.0           202911.0     81525000.0
# PAI LOU L                       NaN                NaN            NaN
# RICE KENNETH D           -3504386.0                NaN            NaN
# SKILLING JEFFREY K              NaN                NaN            NaN
#
#                          other  expenses  director_fees  ...  \
# HIRKO JOSEPH            2856.0   77978.0            NaN  ...
# LAY KENNETH L       10359729.0   99832.0            NaN  ...
# PAI LOU L            1829457.0   32047.0            NaN  ...
# RICE KENNETH D        174839.0   46950.0            NaN  ...
# SKILLING JEFFREY K     22122.0   29336.0            NaN  ...
#
#                     exercised_stock_options  restricted_stock  \
# HIRKO JOSEPH                     30766064.0               NaN
# LAY KENNETH L                    34348384.0        14761694.0
# PAI LOU L                        15364167.0         8453763.0
# RICE KENNETH D                   19794175.0         2748364.0
# SKILLING JEFFREY K               19250000.0         6843672.0
#
#                     restricted_stock_deferred  total_stock_value  \
# HIRKO JOSEPH                              NaN         30766064.0
# LAY KENNETH L                             NaN         49110078.0
# PAI LOU L                                 NaN         23817930.0
# RICE KENNETH D                            NaN         22542539.0
# SKILLING JEFFREY K                        NaN         26093672.0
#
#                               email_address to_messages  from_messages  \
# HIRKO JOSEPH            joe.hirko@enron.com         NaN            NaN
# LAY KENNETH L         kenneth.lay@enron.com      4273.0           36.0
# PAI LOU L                 lou.pai@enron.com         NaN            NaN
# RICE KENNETH D           ken.rice@enron.com       905.0           18.0
# SKILLING JEFFREY K  jeff.skilling@enron.com      3627.0          108.0
#
#                     from_this_person_to_poi  from_poi_to_this_person  \
# HIRKO JOSEPH                            NaN                      NaN
# LAY KENNETH L                          16.0                    123.0
# PAI LOU L                               NaN                      NaN
# RICE KENNETH D                          4.0                     42.0
# SKILLING JEFFREY K                     30.0                     88.0
#
#                     shared_receipt_with_poi
# HIRKO JOSEPH                            NaN
# LAY KENNETH L                        2411.0
# PAI LOU L                               NaN
# RICE KENNETH D                        864.0
# SKILLING JEFFREY K                   2042.0
#
# [5 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['restricted_stock_deferred'] <= -500000 ]
# Out:
#                      poi    salary     bonus  long_term_incentive  \
# BANNANTINE JAMES M     0     477.0       NaN                  NaN
# DERRICK JR. JAMES V    0  492375.0  800000.0             484000.0
#
#                      deferred_income  deferral_payments  loan_advances  \
# BANNANTINE JAMES M           -5104.0                NaN            NaN
# DERRICK JR. JAMES V       -1284000.0                NaN            NaN
#
#                         other  expenses  director_fees  ...  \
# BANNANTINE JAMES M   864523.0   56301.0            NaN  ...
# DERRICK JR. JAMES V    7482.0   51124.0            NaN  ...
#
#                      exercised_stock_options  restricted_stock  \
# BANNANTINE JAMES M                 4046157.0         1757552.0
# DERRICK JR. JAMES V                8831913.0         1787380.0
#
#                      restricted_stock_deferred  total_stock_value  \
# BANNANTINE JAMES M                   -560222.0          5243487.0
# DERRICK JR. JAMES V                 -1787380.0          8831913.0
#
#                                   email_address to_messages  from_messages  \
# BANNANTINE JAMES M   james.bannantine@enron.com       566.0           29.0
# DERRICK JR. JAMES V     james.derrick@enron.com      2181.0          909.0
#
#                      from_this_person_to_poi  from_poi_to_this_person  \
# BANNANTINE JAMES M                       0.0                     39.0
# DERRICK JR. JAMES V                     20.0                     64.0
#
#                      shared_receipt_with_poi
# BANNANTINE JAMES M                     465.0
# DERRICK JR. JAMES V                   1401.0
#
# [2 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['restricted_stock'] >= 10000000 ]
# Out:
#                    poi     salary      bonus  long_term_incentive  \
# LAY KENNETH L        1  1072321.0  7000000.0            3600000.0
# WHITE JR THOMAS E    0   317543.0   450000.0                  NaN
#
#                    deferred_income  deferral_payments  loan_advances  \
# LAY KENNETH L            -300000.0           202911.0     81525000.0
# WHITE JR THOMAS E              NaN                NaN            NaN
#
#                         other  expenses  director_fees  ...  \
# LAY KENNETH L      10359729.0   99832.0            NaN  ...
# WHITE JR THOMAS E   1085463.0   81353.0            NaN  ...
#
#                    exercised_stock_options  restricted_stock  \
# LAY KENNETH L                   34348384.0        14761694.0
# WHITE JR THOMAS E                1297049.0        13847074.0
#
#                    restricted_stock_deferred  total_stock_value  \
# LAY KENNETH L                            NaN         49110078.0
# WHITE JR THOMAS E                        NaN         15144123.0
#
#                             email_address to_messages  from_messages  \
# LAY KENNETH L       kenneth.lay@enron.com      4273.0           36.0
# WHITE JR THOMAS E  thomas.white@enron.com         NaN            NaN
#
#                    from_this_person_to_poi  from_poi_to_this_person  \
# LAY KENNETH L                         16.0                    123.0
# WHITE JR THOMAS E                      NaN                      NaN
#
#                    shared_receipt_with_poi
# LAY KENNETH L                       2411.0
# WHITE JR THOMAS E                      NaN
#
# [2 rows x 21 columns]

# %%
# Checked, OK
data_Frame[ data_Frame['total_payments'].isna() ].loc[ data_Frame['total_stock_value'].isna() ]
# Out:
#                    poi  salary  bonus  long_term_incentive  deferred_income  \
# CHAN RONNIE          0     NaN    NaN                  NaN         -98784.0
# LOCKHART EUGENE E    0     NaN    NaN                  NaN              NaN
# POWERS WILLIAM       0     NaN    NaN                  NaN         -17500.0
#
#                    deferral_payments  loan_advances  other  expenses  \
# CHAN RONNIE                      NaN            NaN    NaN       NaN
# LOCKHART EUGENE E                NaN            NaN    NaN       NaN
# POWERS WILLIAM                   NaN            NaN    NaN       NaN
#
#                    director_fees  ...  exercised_stock_options  \
# CHAN RONNIE              98784.0  ...                      NaN
# LOCKHART EUGENE E            NaN  ...                      NaN
# POWERS WILLIAM           17500.0  ...                      NaN
#
#                    restricted_stock  restricted_stock_deferred  \
# CHAN RONNIE                 32460.0                   -32460.0
# LOCKHART EUGENE E               NaN                        NaN
# POWERS WILLIAM                  NaN                        NaN
#
#                    total_stock_value         email_address to_messages  \
# CHAN RONNIE                      NaN                   NaN         NaN
# LOCKHART EUGENE E                NaN                   NaN         NaN
# POWERS WILLIAM                   NaN  ken.powers@enron.com       653.0
#
#                    from_messages  from_this_person_to_poi  \
# CHAN RONNIE                  NaN                      NaN
# LOCKHART EUGENE E            NaN                      NaN
# POWERS WILLIAM              26.0                      0.0
#
#                    from_poi_to_this_person  shared_receipt_with_poi
# CHAN RONNIE                            NaN                      NaN
# LOCKHART EUGENE E                      NaN                      NaN
# POWERS WILLIAM                         0.0                     12.0
#
# [3 rows x 21 columns]

# %%
data_Frame[ data_Frame['restricted_stock_deferred'].notna()  ][ ['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments', 
           'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value'] ]
# Out:
#                        salary      bonus  long_term_incentive  \
# ALLEN PHILLIP K      201955.0  4175000.0             304805.0
# BANNANTINE JAMES M      477.0        NaN                  NaN
# BAY FRANKLIN R       239671.0   400000.0                  NaN
# BELFER ROBERT             NaN        NaN                  NaN
# BHATNAGAR SANJAY          NaN        NaN                  NaN
# CARTER REBECCA C     261809.0   300000.0              75000.0
# CHAN RONNIE               NaN        NaN                  NaN
# CLINE KENNETH W           NaN        NaN                  NaN
# DERRICK JR. JAMES V  492375.0   800000.0             484000.0
# DETMERING TIMOTHY J  210500.0   425000.0             415657.0
# GATHMANN WILLIAM D        NaN        NaN                  NaN
# HAEDICKE MARK E      374125.0  1150000.0             983346.0
# JAEDICKE ROBERT           NaN        NaN                  NaN
# LOWRY CHARLES P           NaN        NaN                  NaN
# NOLES JAMES L             NaN        NaN                  NaN
# PIPER GREGORY F      197091.0   400000.0                  NaN
# REYNOLDS LAWRENCE     76399.0   100000.0             156250.0
#
#                      deferred_income  deferral_payments  loan_advances  \
# ALLEN PHILLIP K           -3081055.0          2869717.0            NaN
# BANNANTINE JAMES M           -5104.0                NaN            NaN
# BAY FRANKLIN R             -201641.0           260455.0            NaN
# BELFER ROBERT                    NaN          -102500.0            NaN
# BHATNAGAR SANJAY                 NaN                NaN            NaN
# CARTER REBECCA C           -159792.0                NaN            NaN
# CHAN RONNIE                 -98784.0                NaN            NaN
# CLINE KENNETH W                  NaN                NaN            NaN
# DERRICK JR. JAMES V       -1284000.0                NaN            NaN
# DETMERING TIMOTHY J        -775241.0           875307.0            NaN
# GATHMANN WILLIAM D               NaN                NaN            NaN
# HAEDICKE MARK E            -934484.0          2157527.0            NaN
# JAEDICKE ROBERT             -25000.0                NaN            NaN
# LOWRY CHARLES P                  NaN                NaN            NaN
# NOLES JAMES L                    NaN           774401.0            NaN
# PIPER GREGORY F             -33333.0          1130036.0            NaN
# REYNOLDS LAWRENCE          -200000.0            51365.0            NaN
#
#                         other  expenses  director_fees  total_payments  \
# ALLEN PHILLIP K         152.0   13868.0            NaN       4484442.0
# BANNANTINE JAMES M   864523.0   56301.0            NaN        916197.0
# BAY FRANKLIN R           69.0  129142.0            NaN        827696.0
# BELFER ROBERT             NaN       NaN         3285.0        102500.0
# BHATNAGAR SANJAY     137864.0       NaN       137864.0      15456290.0
# CARTER REBECCA C        540.0       NaN            NaN        477557.0
# CHAN RONNIE               NaN       NaN        98784.0             NaN
# CLINE KENNETH W           NaN       NaN            NaN             NaN
# DERRICK JR. JAMES V    7482.0   51124.0            NaN        550981.0
# DETMERING TIMOTHY J    1105.0   52255.0            NaN       1204583.0
# GATHMANN WILLIAM D        NaN       NaN            NaN             NaN
# HAEDICKE MARK E       52382.0   76169.0            NaN       3859065.0
# JAEDICKE ROBERT           NaN       NaN       108750.0         83750.0
# LOWRY CHARLES P           NaN       NaN            NaN             NaN
# NOLES JAMES L             NaN       NaN            NaN        774401.0
# PIPER GREGORY F         778.0   43057.0            NaN       1737629.0
# REYNOLDS LAWRENCE    202052.0    8409.0            NaN        394475.0
#
#                      exercised_stock_options  restricted_stock  \
# ALLEN PHILLIP K                    1729541.0          126027.0
# BANNANTINE JAMES M                 4046157.0         1757552.0
# BAY FRANKLIN R                           NaN          145796.0
# BELFER ROBERT                         3285.0               NaN
# BHATNAGAR SANJAY                   2604490.0        -2604490.0
# CARTER REBECCA C                         NaN          307301.0
# CHAN RONNIE                              NaN           32460.0
# CLINE KENNETH W                          NaN          662086.0
# DERRICK JR. JAMES V                8831913.0         1787380.0
# DETMERING TIMOTHY J                2027865.0          315068.0
# GATHMANN WILLIAM D                 1753766.0          264013.0
# HAEDICKE MARK E                     608750.0          524169.0
# JAEDICKE ROBERT                     431750.0           44093.0
# LOWRY CHARLES P                     372205.0          153686.0
# NOLES JAMES L                            NaN          463261.0
# PIPER GREGORY F                     880290.0          409554.0
# REYNOLDS LAWRENCE                  4160672.0          201483.0
#
#                      restricted_stock_deferred  total_stock_value
# ALLEN PHILLIP K                      -126027.0          1729541.0
# BANNANTINE JAMES M                   -560222.0          5243487.0
# BAY FRANKLIN R                        -82782.0            63014.0
# BELFER ROBERT                          44093.0           -44093.0
# BHATNAGAR SANJAY                    15456290.0                NaN
# CARTER REBECCA C                     -307301.0                NaN
# CHAN RONNIE                           -32460.0                NaN
# CLINE KENNETH W                      -472568.0           189518.0
# DERRICK JR. JAMES V                 -1787380.0          8831913.0
# DETMERING TIMOTHY J                  -315068.0          2027865.0
# GATHMANN WILLIAM D                    -72419.0          1945360.0
# HAEDICKE MARK E                      -329825.0           803094.0
# JAEDICKE ROBERT                       -44093.0           431750.0
# LOWRY CHARLES P                      -153686.0           372205.0
# NOLES JAMES L                         -94556.0           368705.0
# PIPER GREGORY F                      -409554.0           880290.0
# REYNOLDS LAWRENCE                    -140264.0          4221891.0

# %%
data_Frame_eval = data_Frame.fillna(value=0.0)
data_Frame_eval['eval_payments'] = data_Frame_eval['salary'] + data_Frame_eval['bonus'] + data_Frame_eval['long_term_incentive'] + data_Frame_eval['deferred_income'] + data_Frame_eval['deferral_payments'] + data_Frame_eval['loan_advances'] + data_Frame_eval['other'] + data_Frame_eval['expenses'] + data_Frame_eval['director_fees'] - data_Frame_eval['total_payments']
data_Frame_eval[ data_Frame_eval['eval_payments'] != 0.0 ][['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments', 'eval_payments', 
           'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value']]
# Out:
#                   salary  bonus  long_term_incentive  deferred_income  \
# BELFER ROBERT        0.0    0.0                  0.0              0.0
# BHATNAGAR SANJAY     0.0    0.0                  0.0              0.0
#
#                   deferral_payments  loan_advances     other  expenses  \
# BELFER ROBERT             -102500.0            0.0       0.0       0.0
# BHATNAGAR SANJAY                0.0            0.0  137864.0       0.0
#
#                   director_fees  total_payments  eval_payments  \
# BELFER ROBERT            3285.0        102500.0      -201715.0
# BHATNAGAR SANJAY       137864.0      15456290.0    -15180562.0
#
#                   exercised_stock_options  restricted_stock  \
# BELFER ROBERT                      3285.0               0.0
# BHATNAGAR SANJAY                2604490.0        -2604490.0
#
#                   restricted_stock_deferred  total_stock_value
# BELFER ROBERT                       44093.0           -44093.0
# BHATNAGAR SANJAY                 15456290.0                0.0

# %%
data_Frame_eval['eval_stock'] = data_Frame_eval['exercised_stock_options'] + data_Frame_eval['restricted_stock'] + data_Frame_eval['restricted_stock_deferred'] - data_Frame_eval['total_stock_value']
data_Frame_eval[ data_Frame_eval['eval_stock'] != 0.0 ][['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments', 'eval_payments', 
           'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value', 'eval_stock'] ]
# Out:
#                   salary  bonus  long_term_incentive  deferred_income  \
# BELFER ROBERT        0.0    0.0                  0.0              0.0
# BHATNAGAR SANJAY     0.0    0.0                  0.0              0.0
#
#                   deferral_payments  loan_advances     other  expenses  \
# BELFER ROBERT             -102500.0            0.0       0.0       0.0
# BHATNAGAR SANJAY                0.0            0.0  137864.0       0.0
#
#                   director_fees  total_payments  eval_payments  \
# BELFER ROBERT            3285.0        102500.0      -201715.0
# BHATNAGAR SANJAY       137864.0      15456290.0    -15180562.0
#
#                   exercised_stock_options  restricted_stock  \
# BELFER ROBERT                      3285.0               0.0
# BHATNAGAR SANJAY                2604490.0        -2604490.0
#
#                   restricted_stock_deferred  total_stock_value  eval_stock
# BELFER ROBERT                       44093.0           -44093.0     91471.0
# BHATNAGAR SANJAY                 15456290.0                0.0  15456290.0

# %%
# Correcting Robert Belfer instance
data_Frame.loc['BELFER ROBERT', 'restricted_stock'] = 44093.0
data_Frame.loc['BELFER ROBERT', 'restricted_stock_deferred'] = -44093.0
data_Frame.loc['BELFER ROBERT', 'exercised_stock_options'] = np.NaN
data_Frame.loc['BELFER ROBERT', 'total_stock_value'] = np.NaN
data_Frame.loc['BELFER ROBERT', 'director_fees'] = 102500.0
data_Frame.loc['BELFER ROBERT', 'deferred_income'] = -102500.0
data_Frame.loc['BELFER ROBERT', 'deferral_payments'] = np.NaN
data_Frame.loc['BELFER ROBERT', 'expenses'] = 3285.0
data_Frame.loc['BELFER ROBERT', 'total_payments'] = 3285.0

# %%
# Correcting BHATNAGAR SANJAY
data_Frame.loc['BHATNAGAR SANJAY', 'other'] = np.NaN
data_Frame.loc['BHATNAGAR SANJAY', 'expenses'] = 137864.0
data_Frame.loc['BHATNAGAR SANJAY', 'director_fees'] = np.NaN
data_Frame.loc['BHATNAGAR SANJAY', 'total_payments'] = 137864.0
data_Frame.loc['BHATNAGAR SANJAY', 'exercised_stock_options'] = 15456290.0
data_Frame.loc['BHATNAGAR SANJAY', 'restricted_stock'] = 2604490.0
data_Frame.loc['BHATNAGAR SANJAY', 'restricted_stock_deferred'] = -2604490.0
data_Frame.loc['BHATNAGAR SANJAY', 'total_stock_value'] = 15456290.0

# %%
data_Frame_eval = data_Frame.fillna(value=0.0)
data_Frame_eval['eval_payments'] = data_Frame_eval['salary'] + data_Frame_eval['bonus'] + data_Frame_eval['long_term_incentive'] + data_Frame_eval['deferred_income'] + data_Frame_eval['deferral_payments'] + data_Frame_eval['loan_advances'] + data_Frame_eval['other'] + data_Frame_eval['expenses'] + data_Frame_eval['director_fees'] - data_Frame_eval['total_payments']
data_Frame_eval['eval_stock'] = data_Frame_eval['exercised_stock_options'] + data_Frame_eval['restricted_stock'] + data_Frame_eval['restricted_stock_deferred'] - data_Frame_eval['total_stock_value']

# %%
data_Frame_eval[ data_Frame_eval['eval_payments'] != 0.0 ][['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments', 'eval_payments', 
           'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value']]
# Out:
# Empty DataFrame
# Columns: [salary, bonus, long_term_incentive, deferred_income, deferral_payments, loan_advances, other, expenses, director_fees, total_payments, eval_payments, exercised_stock_options, restricted_stock, restricted_stock_deferred, total_stock_value]
# Index: []

# %%
data_Frame.loc[ ['BELFER ROBERT', 'BHATNAGAR SANJAY'] ][['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments', 
           'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value']].transpose()
# Out:
#                            BELFER ROBERT  BHATNAGAR SANJAY
# salary                               NaN               NaN
# bonus                                NaN               NaN
# long_term_incentive                  NaN               NaN
# deferred_income                -102500.0               NaN
# deferral_payments                    NaN               NaN
# loan_advances                        NaN               NaN
# other                                NaN               NaN
# expenses                          3285.0          137864.0
# director_fees                   102500.0               NaN
# total_payments                    3285.0          137864.0
# exercised_stock_options              NaN        15456290.0
# restricted_stock                 44093.0         2604490.0
# restricted_stock_deferred       -44093.0        -2604490.0
# total_stock_value                    NaN        15456290.0

# %%
# After correctiong the data we check the boxplots again
crt_plot(data_Frame, ['poi'] + feature_list, shape=(4,5), log=log_list, sort=False, save=IMAGES+"features_box_plots_corrected")

# %%
# Check email

# %%
# Checked, OK
data_Frame[ data_Frame['to_messages'] >= 8000 ]
# Out:
#                    poi    salary      bonus  long_term_incentive  \
# KEAN STEVEN J        0  404338.0  1000000.0             300000.0
# KITCHEN LOUISE       0  271442.0  3100000.0                  NaN
# SHAPIRO RICHARD S    0  269076.0   650000.0                  NaN
#
#                    deferred_income  deferral_payments  loan_advances    other  \
# KEAN STEVEN J                  NaN                NaN            NaN   1231.0
# KITCHEN LOUISE                 NaN                NaN            NaN  93925.0
# SHAPIRO RICHARD S              NaN                NaN            NaN    705.0
#
#                    expenses  director_fees  ...  exercised_stock_options  \
# KEAN STEVEN J       41953.0            NaN  ...                2022048.0
# KITCHEN LOUISE       5774.0            NaN  ...                  81042.0
# SHAPIRO RICHARD S  137767.0            NaN  ...                 607837.0
#
#                    restricted_stock  restricted_stock_deferred  \
# KEAN STEVEN J             4131594.0                        NaN
# KITCHEN LOUISE             466101.0                        NaN
# SHAPIRO RICHARD S          379164.0                        NaN
#
#                    total_stock_value              email_address to_messages  \
# KEAN STEVEN J              6153642.0      steven.kean@enron.com     12754.0
# KITCHEN LOUISE              547143.0   louise.kitchen@enron.com      8305.0
# SHAPIRO RICHARD S           987001.0  richard.shapiro@enron.com     15149.0
#
#                    from_messages  from_this_person_to_poi  \
# KEAN STEVEN J             6759.0                    387.0
# KITCHEN LOUISE            1728.0                    194.0
# SHAPIRO RICHARD S         1215.0                     65.0
#
#                    from_poi_to_this_person  shared_receipt_with_poi
# KEAN STEVEN J                        140.0                   3639.0
# KITCHEN LOUISE                       251.0                   3669.0
# SHAPIRO RICHARD S                     74.0                   4527.0
#
# [3 rows x 21 columns]

# %%
# Checked, Kaminski doesn't look correct. He clearly didn't send 14k mails and just received 4600.
data_Frame[ data_Frame['from_messages'] >= 5000 ][['poi']+mail_features].transpose()
# Out:
#                          KAMINSKI WINCENTY J  KEAN STEVEN J
# poi                                      0.0            0.0
# to_messages                           4607.0        12754.0
# from_messages                        14368.0         6759.0
# from_this_person_to_poi                171.0          387.0
# from_poi_to_this_person                 41.0          140.0
# shared_receipt_with_poi                583.0         3639.0

# %%
# I'll use median mail values for Kaminski as the current values are not trustworthy to me. Unfortunately I cannot resolve where or how this data was generated.
data_Frame[mail_features].median()
# Out:
# to_messages                1211.0
# from_messages                41.0
# from_this_person_to_poi       8.0
# from_poi_to_this_person      35.0
# shared_receipt_with_poi     740.5
# dtype: float64

# %%
data_Frame.loc['KAMINSKI WINCENTY J', mail_features] = data_Frame[mail_features].median()

# %%
data_Frame.loc['KAMINSKI WINCENTY J', mail_features]
# Out:
# to_messages                 1211
# from_messages                 41
# from_this_person_to_poi        8
# from_poi_to_this_person       35
# shared_receipt_with_poi    740.5
# Name: KAMINSKI WINCENTY J, dtype: object

# %%
# Checked, OK
data_Frame[ data_Frame['from_this_person_to_poi'] >= 300 ][mail_features]
# Out:
#                   to_messages  from_messages  from_this_person_to_poi  \
# BECK SALLY W           7315.0         4343.0                    386.0
# DELAINEY DAVID W       3093.0         3069.0                    609.0
# KEAN STEVEN J         12754.0         6759.0                    387.0
# LAVORATO JOHN J        7259.0         2585.0                    411.0
#
#                   from_poi_to_this_person  shared_receipt_with_poi
# BECK SALLY W                        144.0                   2639.0
# DELAINEY DAVID W                     66.0                   2097.0
# KEAN STEVEN J                       140.0                   3639.0
# LAVORATO JOHN J                     528.0                   3962.0

# %%
# Checked, OK
data_Frame[ data_Frame['from_poi_to_this_person'] >= 250 ][mail_features]
# Out:
#                   to_messages  from_messages  from_this_person_to_poi  \
# DIETRICH JANET R       2572.0           63.0                     14.0
# KITCHEN LOUISE         8305.0         1728.0                    194.0
# LAVORATO JOHN J        7259.0         2585.0                    411.0
#
#                   from_poi_to_this_person  shared_receipt_with_poi
# DIETRICH JANET R                    305.0                   1902.0
# KITCHEN LOUISE                      251.0                   3669.0
# LAVORATO JOHN J                     528.0                   3962.0

# %%
# Checked, OK
data_Frame[ data_Frame['shared_receipt_with_poi'] >= 3000 ][mail_features]
# Out:
#                     to_messages  from_messages  from_this_person_to_poi  \
# BELDEN TIMOTHY N         7991.0          484.0                    108.0
# KEAN STEVEN J           12754.0         6759.0                    387.0
# KITCHEN LOUISE           8305.0         1728.0                    194.0
# LAVORATO JOHN J          7259.0         2585.0                    411.0
# SHAPIRO RICHARD S       15149.0         1215.0                     65.0
# WHALLEY LAWRENCE G       6019.0          556.0                     24.0
#
#                     from_poi_to_this_person  shared_receipt_with_poi
# BELDEN TIMOTHY N                      228.0                   5521.0
# KEAN STEVEN J                         140.0                   3639.0
# KITCHEN LOUISE                        251.0                   3669.0
# LAVORATO JOHN J                       528.0                   3962.0
# SHAPIRO RICHARD S                      74.0                   4527.0
# WHALLEY LAWRENCE G                    186.0                   3920.0

# %% [markdown]
# There are still many outlyer in the data. As extreme values might be an indication for fraud or any other irregular operation I'll keep the remaining data as is.
# Data that I will not use for ML are:
#
# + *email_address* (no value)
# + *loan_advances* (only 4 instances)
# + *to_messages* (indirectly used for new features)
# + *from_messages* (indirectly used for new features)

# %%
feature_list
# Out:
# ['salary',
#  'bonus',
#  'long_term_incentive',
#  'deferred_income',
#  'deferral_payments',
#  'loan_advances',
#  'other',
#  'expenses',
#  'director_fees',
#  'total_payments',
#  'exercised_stock_options',
#  'restricted_stock',
#  'restricted_stock_deferred',
#  'total_stock_value',
#  'to_messages',
#  'from_messages',
#  'from_this_person_to_poi',
#  'from_poi_to_this_person',
#  'shared_receipt_with_poi']

# %%
### Task 3: Create new feature(s)

# %%
remove_lst =  ['loan_advances', 'to_messages', 'from_messages' ]
# remove_lst =  ['loan_advances' ]
correlate = ['poi'] + feature_list
for instance in remove_lst:
    if instance in correlate:
        correlate.remove(instance)

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(data_Frame[correlate], figsize=(30, 30), hist_kwds={'bins':20} );
plt.savefig(IMAGES+"scatter_matrix_big", dpi='figure')

# %%
data_Frame[correlate].corr()
# Out:
#                                 poi    salary     bonus  long_term_incentive  \
# poi                        1.000000  0.264976  0.302384             0.254723
# salary                     0.264976  1.000000  0.523190             0.484114
# bonus                      0.302384  0.523190  1.000000             0.625259
# long_term_incentive        0.254723  0.484114  0.625259             1.000000
# deferred_income           -0.269866 -0.353816 -0.411659            -0.331715
# deferral_payments         -0.107254  0.455884  0.293543             0.042448
# other                      0.119166  0.606903  0.376371             0.529398
# expenses                   0.055209  0.145364  0.033799            -0.100766
# director_fees                   NaN       NaN       NaN                  NaN
# total_payments             0.237288  0.579260  0.569054             0.518498
# exercised_stock_options    0.481875  0.607324  0.506998             0.500016
# restricted_stock           0.219666  0.550824  0.376992             0.635172
# restricted_stock_deferred       NaN -0.592576  0.118222            -0.186597
# total_stock_value          0.354220  0.614736  0.509441             0.495485
# from_this_person_to_poi    0.122501  0.026189  0.372119             0.099781
# from_poi_to_this_person    0.168036  0.179184  0.562577             0.213118
# shared_receipt_with_poi    0.227781  0.284922  0.548556             0.177723
#
#                            deferred_income  deferral_payments     other  \
# poi                              -0.269866          -0.107254  0.119166
# salary                           -0.353816           0.455884  0.606903
# bonus                            -0.411659           0.293543  0.376371
# long_term_incentive              -0.331715           0.042448  0.529398
# deferred_income                   1.000000          -0.881500 -0.185219
# deferral_payments                -0.881500           1.000000  0.385829
# other                            -0.185219           0.385829  1.000000
# expenses                          0.085678           0.004800  0.062874
# director_fees                    -0.474047                NaN       NaN
# total_payments                   -0.057065           0.061585  0.834424
# exercised_stock_options          -0.308076           0.006560  0.535934
# restricted_stock                 -0.140510           0.115088  0.650015
# restricted_stock_deferred         0.200362          -0.217200 -0.029366
# total_stock_value                -0.298189           0.066470  0.627171
# from_this_person_to_poi          -0.271673           0.206993 -0.105986
# from_poi_to_this_person          -0.178951           0.424101  0.109124
# shared_receipt_with_poi          -0.394677           0.356696  0.119894
#
#                            expenses  director_fees  total_payments  \
# poi                        0.055209            NaN        0.237288
# salary                     0.145364            NaN        0.579260
# bonus                      0.033799            NaN        0.569054
# long_term_incentive       -0.100766            NaN        0.518498
# deferred_income            0.085678      -0.474047       -0.057065
# deferral_payments          0.004800            NaN        0.061585
# other                      0.062874            NaN        0.834424
# expenses                   1.000000      -0.521463        0.105375
# director_fees             -0.521463       1.000000       -0.233928
# total_payments             0.105375      -0.233928        1.000000
# exercised_stock_options    0.066763       0.769988        0.575716
# restricted_stock           0.060546       0.784221        0.626467
# restricted_stock_deferred -0.527262      -0.784221        0.228501
# total_stock_value          0.065689       0.769988        0.654867
# from_this_person_to_poi   -0.011673            NaN        0.023537
# from_poi_to_this_person   -0.082448            NaN        0.169070
# shared_receipt_with_poi    0.196007            NaN        0.203906
#
#                            exercised_stock_options  restricted_stock  \
# poi                                       0.481875          0.219666
# salary                                    0.607324          0.550824
# bonus                                     0.506998          0.376992
# long_term_incentive                       0.500016          0.635172
# deferred_income                          -0.308076         -0.140510
# deferral_payments                         0.006560          0.115088
# other                                     0.535934          0.650015
# expenses                                  0.066763          0.060546
# director_fees                             0.769988          0.784221
# total_payments                            0.575716          0.626467
# exercised_stock_options                   1.000000          0.689184
# restricted_stock                          0.689184          1.000000
# restricted_stock_deferred                -0.953665         -0.918346
# total_stock_value                         0.962760          0.851009
# from_this_person_to_poi                  -0.034714          0.045745
# from_poi_to_this_person                   0.128570          0.107960
# shared_receipt_with_poi                   0.125683          0.212029
#
#                            restricted_stock_deferred  total_stock_value  \
# poi                                              NaN           0.354220
# salary                                     -0.592576           0.614736
# bonus                                       0.118222           0.509441
# long_term_incentive                        -0.186597           0.495485
# deferred_income                             0.200362          -0.298189
# deferral_payments                          -0.217200           0.066470
# other                                      -0.029366           0.627171
# expenses                                   -0.527262           0.065689
# director_fees                              -0.784221           0.769988
# total_payments                              0.228501           0.654867
# exercised_stock_options                    -0.953665           0.962760
# restricted_stock                           -0.918346           0.851009
# restricted_stock_deferred                   1.000000          -0.935020
# total_stock_value                          -0.935020           1.000000
# from_this_person_to_poi                     0.548367          -0.000659
# from_poi_to_this_person                     0.409103           0.126061
# shared_receipt_with_poi                     0.167165           0.157364
#
#                            from_this_person_to_poi  from_poi_to_this_person  \
# poi                                       0.122501                 0.168036
# salary                                    0.026189                 0.179184
# bonus                                     0.372119                 0.562577
# long_term_incentive                       0.099781                 0.213118
# deferred_income                          -0.271673                -0.178951
# deferral_payments                         0.206993                 0.424101
# other                                    -0.105986                 0.109124
# expenses                                 -0.011673                -0.082448
# director_fees                                  NaN                      NaN
# total_payments                            0.023537                 0.169070
# exercised_stock_options                  -0.034714                 0.128570
# restricted_stock                          0.045745                 0.107960
# restricted_stock_deferred                 0.548367                 0.409103
# total_stock_value                        -0.000659                 0.126061
# from_this_person_to_poi                   1.000000                 0.454775
# from_poi_to_this_person                   0.454775                 1.000000
# shared_receipt_with_poi                   0.489879                 0.659422
#
#                            shared_receipt_with_poi
# poi                                       0.227781
# salary                                    0.284922
# bonus                                     0.548556
# long_term_incentive                       0.177723
# deferred_income                          -0.394677
# deferral_payments                         0.356696
# other                                     0.119894
# expenses                                  0.196007
# director_fees                                  NaN
# total_payments                            0.203906
# exercised_stock_options                   0.125683
# restricted_stock                          0.212029
# restricted_stock_deferred                 0.167165
# total_stock_value                         0.157364
# from_this_person_to_poi                   0.489879
# from_poi_to_this_person                   0.659422
# shared_receipt_with_poi                   1.000000

# %%
# Create new email features

# %%
fromPOI_rate = data_Frame['from_poi_to_this_person'].div(data_Frame['to_messages'])
fromPOI_rate[ fromPOI_rate>0.1 ]
# Out:
# COLWELL WESLEY          0.136519
# DEFFNER JOSEPH M        0.161064
# DIETRICH JANET R        0.118585
# DONAHUE JR JEFFREY M    0.217341
# DURAN WILLIAM D         0.117257
# REDMOND BRIAN L         0.122083
# UMANOFF ADAM S          0.108108
# dtype: float64

# %%
data_Frame.corrwith(fromPOI_rate)
# Out:
# poi                          0.102142
# salary                      -0.132854
# bonus                       -0.067144
# long_term_incentive          0.002981
# deferred_income              0.148719
# deferral_payments            0.241365
# loan_advances               -0.189228
# other                       -0.024249
# expenses                    -0.140247
# director_fees                     NaN
# total_payments              -0.028805
# exercised_stock_options     -0.014823
# restricted_stock            -0.078101
# restricted_stock_deferred    0.601993
# total_stock_value           -0.018542
# to_messages                 -0.125420
# from_messages               -0.114726
# from_this_person_to_poi     -0.041439
# from_poi_to_this_person      0.468746
# shared_receipt_with_poi     -0.040087
# dtype: float64

# %%
toPOI_rate = data_Frame['from_this_person_to_poi'].div(data_Frame['from_messages'])
toPOI_rate[toPOI_rate>0.5]
# Out:
# BOWEN JR RAYMOND M    0.555556
# GARLAND C KEVIN       0.613636
# HANNON KEVIN P        0.656250
# HUMPHREY GENE E       1.000000
# MCMAHON JEFFREY       0.541667
# RIEKER PAULA H        0.585366
# SHERRICK JEFFREY B    0.720000
# TILNEY ELIZABETH A    0.578947
# dtype: float64

# %%
# toPOI_rate of 1.0? But looks OK as he only wrote/received 17 mails 
data_Frame.loc['HUMPHREY GENE E']
# Out:
# poi                                                0
# salary                                        130724
# bonus                                            NaN
# long_term_incentive                              NaN
# deferred_income                                  NaN
# deferral_payments                        2.96451e+06
# loan_advances                                    NaN
# other                                            NaN
# expenses                                        4994
# director_fees                                    NaN
# total_payments                           3.10022e+06
# exercised_stock_options                  2.28277e+06
# restricted_stock                                 NaN
# restricted_stock_deferred                        NaN
# total_stock_value                        2.28277e+06
# email_address                gene.humphrey@enron.com
# to_messages                                      128
# from_messages                                     17
# from_this_person_to_poi                           17
# from_poi_to_this_person                           10
# shared_receipt_with_poi                          119
# Name: HUMPHREY GENE E, dtype: object

# %%
data_Frame.corrwith(toPOI_rate)
# Out:
# poi                          0.336790
# salary                       0.001939
# bonus                        0.058552
# long_term_incentive          0.017642
# deferred_income             -0.019555
# deferral_payments            0.202902
# loan_advances                0.783924
# other                        0.138594
# expenses                    -0.146743
# director_fees                     NaN
# total_payments               0.142147
# exercised_stock_options      0.101623
# restricted_stock             0.132477
# restricted_stock_deferred    0.335506
# total_stock_value            0.120485
# to_messages                 -0.118138
# from_messages               -0.194396
# from_this_person_to_poi     -0.034778
# from_poi_to_this_person      0.060067
# shared_receipt_with_poi      0.032689
# dtype: float64

# %%
mail_ratio = data_Frame['from_messages'].div(data_Frame['to_messages'])

# %%
mail_ratio[mail_ratio > 0.5]
# Out:
# ALLEN PHILLIP K        0.756375
# BECK SALLY W           0.593712
# DELAINEY DAVID W       0.992241
# KEAN STEVEN J          0.529951
# MCCONNELL MICHAEL S    0.823671
# SHANKMAN JEFFREY A     0.832350
# dtype: float64

# %%
A = data_Frame['deferred_income'].div(data_Frame['total_payments'].sub(data_Frame['deferred_income']))
data_Frame[A<-0.8][payment_features]
# Out:
#                       salary      bonus  long_term_incentive  deferred_income  \
# BELFER ROBERT            NaN        NaN                  NaN        -102500.0
# BLAKE JR. NORMAN P       NaN        NaN                  NaN        -113784.0
# HANNON KEVIN P      243293.0  1500000.0            1617011.0       -3117011.0
# MENDELSOHN JOHN          NaN        NaN                  NaN        -103750.0
# MEYER JEROME J           NaN        NaN                  NaN         -38346.0
# RICE KENNETH D      420636.0  1750000.0            1617011.0       -3504386.0
# SAVAGE FRANK             NaN        NaN                  NaN        -121284.0
#
#                     deferral_payments  loan_advances     other  expenses  \
# BELFER ROBERT                     NaN            NaN       NaN    3285.0
# BLAKE JR. NORMAN P                NaN            NaN       NaN    1279.0
# HANNON KEVIN P                    NaN            NaN   11350.0   34039.0
# MENDELSOHN JOHN                   NaN            NaN       NaN     148.0
# MEYER JEROME J                    NaN            NaN       NaN    2151.0
# RICE KENNETH D                    NaN            NaN  174839.0   46950.0
# SAVAGE FRANK                      NaN            NaN       NaN       NaN
#
#                     director_fees  total_payments
# BELFER ROBERT            102500.0          3285.0
# BLAKE JR. NORMAN P       113784.0          1279.0
# HANNON KEVIN P                NaN        288682.0
# MENDELSOHN JOHN          103750.0           148.0
# MEYER JEROME J            38346.0          2151.0
# RICE KENNETH D                NaN        505050.0
# SAVAGE FRANK             125034.0          3750.0

# %%
data_Frame.corrwith(A)
# Out:
# poi                          0.123065
# salary                       0.009314
# bonus                        0.054615
# long_term_incentive          0.024098
# deferred_income              0.257247
# deferral_payments           -0.195079
# loan_advances                1.000000
# other                        0.215877
# expenses                     0.334298
# director_fees               -0.118700
# total_payments               0.196671
# exercised_stock_options     -0.155070
# restricted_stock             0.101348
# restricted_stock_deferred    0.211969
# total_stock_value           -0.125850
# to_messages                  0.082057
# from_messages               -0.131308
# from_this_person_to_poi      0.009486
# from_poi_to_this_person      0.238743
# shared_receipt_with_poi      0.067230
# dtype: float64

# %%
B = data_Frame['exercised_stock_options'].div( data_Frame['total_payments'])
data_Frame.corrwith(B)
# Out:
# poi                          0.274168
# salary                      -0.147846
# bonus                       -0.055511
# long_term_incentive          0.037940
# deferred_income             -0.427536
# deferral_payments           -0.140998
# loan_advances                0.054608
# other                       -0.059255
# expenses                     0.087532
# director_fees               -0.024745
# total_payments              -0.060580
# exercised_stock_options      0.590854
# restricted_stock             0.046832
# restricted_stock_deferred   -0.857997
# total_stock_value            0.443807
# to_messages                 -0.122866
# from_messages               -0.091901
# from_this_person_to_poi     -0.077673
# from_poi_to_this_person     -0.026440
# shared_receipt_with_poi     -0.125226
# dtype: float64

# %%
C = data_Frame['bonus'].div( data_Frame['deferral_payments'])
data_Frame.corrwith(C)
# Out:
# poi                          0.665900
# salary                       0.375967
# bonus                        0.412695
# long_term_incentive          0.719694
# deferred_income              0.290512
# deferral_payments           -0.263022
# loan_advances                1.000000
# other                        0.396003
# expenses                    -0.009878
# director_fees                     NaN
# total_payments               0.552646
# exercised_stock_options      0.873960
# restricted_stock             0.525540
# restricted_stock_deferred    0.926062
# total_stock_value            0.497049
# to_messages                  0.043722
# from_messages               -0.275180
# from_this_person_to_poi     -0.267476
# from_poi_to_this_person      0.347905
# shared_receipt_with_poi     -0.011730
# dtype: float64

# %%
data_Frame[ C > 2]
# Out:
#                    poi     salary      bonus  long_term_incentive  \
# BELDEN TIMOTHY N     1   213999.0  5249999.0                  NaN
# COLWELL WESLEY       1   288542.0  1200000.0                  NaN
# GAHN ROBERT S        0   192008.0   509870.0                  NaN
# LAY KENNETH L        1  1072321.0  7000000.0            3600000.0
# OLSON CINDY K        0   329078.0   750000.0             100000.0
# RIEKER PAULA H       1   249201.0   700000.0                  NaN
# SHARP VICTORIA T     0   248146.0   600000.0             422158.0
# TAYLOR MITCHELL S    0   265214.0   600000.0                  NaN
#
#                    deferred_income  deferral_payments  loan_advances  \
# BELDEN TIMOTHY N        -2334434.0          2144013.0            NaN
# COLWELL WESLEY           -144062.0            27610.0            NaN
# GAHN ROBERT S              -1042.0            73122.0            NaN
# LAY KENNETH L            -300000.0           202911.0     81525000.0
# OLSON CINDY K                  NaN            77716.0            NaN
# RIEKER PAULA H           -100000.0           214678.0            NaN
# SHARP VICTORIA T               NaN           187469.0            NaN
# TAYLOR MITCHELL S              NaN           227449.0            NaN
#
#                         other  expenses  director_fees  ...  \
# BELDEN TIMOTHY N     210698.0   17355.0            NaN  ...
# COLWELL WESLEY       101740.0   16514.0            NaN  ...
# GAHN ROBERT S         76547.0   50080.0            NaN  ...
# LAY KENNETH L      10359729.0   99832.0            NaN  ...
# OLSON CINDY K           972.0   63791.0            NaN  ...
# RIEKER PAULA H         1950.0   33271.0            NaN  ...
# SHARP VICTORIA T       2401.0  116337.0            NaN  ...
# TAYLOR MITCHELL S         NaN       NaN            NaN  ...
#
#                    exercised_stock_options  restricted_stock  \
# BELDEN TIMOTHY N                  953136.0          157569.0
# COLWELL WESLEY                         NaN          698242.0
# GAHN ROBERT S                      83237.0          235370.0
# LAY KENNETH L                   34348384.0        14761694.0
# OLSON CINDY K                    1637034.0          969729.0
# RIEKER PAULA H                   1635238.0          283649.0
# SHARP VICTORIA T                  281073.0          213063.0
# TAYLOR MITCHELL S                3181250.0          563798.0
#
#                    restricted_stock_deferred  total_stock_value  \
# BELDEN TIMOTHY N                         NaN          1110705.0
# COLWELL WESLEY                           NaN           698242.0
# GAHN ROBERT S                            NaN           318607.0
# LAY KENNETH L                            NaN         49110078.0
# OLSON CINDY K                            NaN          2606763.0
# RIEKER PAULA H                           NaN          1918887.0
# SHARP VICTORIA T                         NaN           494136.0
# TAYLOR MITCHELL S                        NaN          3745048.0
#
#                                email_address to_messages  from_messages  \
# BELDEN TIMOTHY N        tim.belden@enron.com      7991.0          484.0
# COLWELL WESLEY         wes.colwell@enron.com      1758.0           40.0
# GAHN ROBERT S                            NaN         NaN            NaN
# LAY KENNETH L          kenneth.lay@enron.com      4273.0           36.0
# OLSON CINDY K          cindy.olson@enron.com      1184.0           52.0
# RIEKER PAULA H        paula.rieker@enron.com      1328.0           82.0
# SHARP VICTORIA T       vicki.sharp@enron.com      3136.0          136.0
# TAYLOR MITCHELL S  mitchell.taylor@enron.com       533.0           29.0
#
#                    from_this_person_to_poi  from_poi_to_this_person  \
# BELDEN TIMOTHY N                     108.0                    228.0
# COLWELL WESLEY                        11.0                    240.0
# GAHN ROBERT S                          NaN                      NaN
# LAY KENNETH L                         16.0                    123.0
# OLSON CINDY K                         15.0                     20.0
# RIEKER PAULA H                        48.0                     35.0
# SHARP VICTORIA T                       6.0                     24.0
# TAYLOR MITCHELL S                      0.0                      0.0
#
#                    shared_receipt_with_poi
# BELDEN TIMOTHY N                    5521.0
# COLWELL WESLEY                      1132.0
# GAHN ROBERT S                          NaN
# LAY KENNETH L                       2411.0
# OLSON CINDY K                        856.0
# RIEKER PAULA H                      1258.0
# SHARP VICTORIA T                    2477.0
# TAYLOR MITCHELL S                    300.0
#
# [8 rows x 21 columns]

# %%
feature_list.remove('loan_advances')

# %%
feature_list
# Out:
# ['salary',
#  'bonus',
#  'long_term_incentive',
#  'deferred_income',
#  'deferral_payments',
#  'other',
#  'expenses',
#  'director_fees',
#  'total_payments',
#  'exercised_stock_options',
#  'restricted_stock',
#  'restricted_stock_deferred',
#  'total_stock_value',
#  'to_messages',
#  'from_messages',
#  'from_this_person_to_poi',
#  'from_poi_to_this_person',
#  'shared_receipt_with_poi']

# %%
# Correlates feature combinations of data frame columns with selected feature
def correlate(frame, corr, feature_list=None):
    correlations = []
    if feature_list == None:
        feature_list = frame.columns
    for feature in feature_list:
        for divisor in feature_list:
            if feature == divisor:
                continue
            try:
                new_feature = frame[feature].div( frame[divisor] )
            except:
                continue
            values = new_feature.count()
            corr_poi = frame.corrwith(new_feature)[corr]
            if not np.isnan(corr_poi):
                correlations.append( [feature, divisor, corr_poi, values] )
    correlations.sort(key=lambda x: abs(x[2]), reverse=True)
    corr_frame = pd.DataFrame(correlations, columns=['feature', 'divisor', 'corr', 'count'])
    return corr_frame

# %%
corr_list = list(feature_list)
corr_df = correlate(data_Frame, 'poi', feature_list=corr_list)
print corr_df[ corr_df['corr'] > 0.15 ]
# Out:
#                     feature                  divisor      corr  count
# 0                     bonus        deferral_payments  0.665900     21
# 1   from_this_person_to_poi        deferral_payments  0.650054     22
# 2   shared_receipt_with_poi        deferral_payments  0.551253     22
# 3          restricted_stock        deferral_payments  0.516681     26
# 4   exercised_stock_options        deferral_payments  0.493101     32
# 5   from_poi_to_this_person        deferral_payments  0.471403     22
# 6         total_stock_value        deferral_payments  0.447212     36
# 7            total_payments        deferral_payments  0.441996     37
# 9   exercised_stock_options            from_messages  0.373662     67
# 11                 expenses        deferral_payments  0.356435     22
# 13  from_this_person_to_poi            from_messages  0.336790     86
# 14              to_messages        deferral_payments  0.336584     22
# 15      long_term_incentive           total_payments  0.326070     65
# 17                   salary        deferral_payments  0.304583     26
# 18        total_stock_value            from_messages  0.301027     81
# 19                    bonus           total_payments  0.297819     81
# 20                    bonus            from_messages  0.297435     61
# 23  exercised_stock_options           total_payments  0.274168     85
# 24          deferred_income      long_term_incentive  0.271228     23
# 25  shared_receipt_with_poi              to_messages  0.260937     86
# 29         restricted_stock            from_messages  0.241390     76
# 30                    other        deferral_payments  0.237200     25
# 32          deferred_income                    bonus  0.220640     33
# 33           total_payments            from_messages  0.219879     75
# 34      long_term_incentive            from_messages  0.219710     48
# 37  from_poi_to_this_person        total_stock_value  0.210536     81
# 38        deferral_payments          deferred_income  0.209445     16
# 39      long_term_incentive        deferral_payments  0.206714     19
# 44  from_poi_to_this_person         restricted_stock  0.191838     76
# 45                    other  shared_receipt_with_poi  0.183978     62
# 47                    bonus                   salary  0.180980     81
# 48  shared_receipt_with_poi         restricted_stock  0.178598     76
# 49  shared_receipt_with_poi            from_messages  0.176336     86
# 52  from_poi_to_this_person            from_messages  0.172783     86
# 53                    other              to_messages  0.170311     62
# 55              to_messages            from_messages  0.163754     86
# 58  from_this_person_to_poi              to_messages  0.155817     86

# %%
# Create new financial features
data_Frame['bonus_deferral_payments_rate']              = data_Frame['bonus'].div( data_Frame['deferral_payments'] )
data_Frame['rest_stock_deferral_payments_rate']         = data_Frame['restricted_stock'].div( data_Frame['deferral_payments'] )
data_Frame['exer_stock_options_deferral_payments_rate'] = data_Frame['exercised_stock_options'].div( data_Frame['deferral_payments'] )

data_Frame['long_term_incentive_total_payments_rate']   = data_Frame['long_term_incentive'].div( data_Frame['total_payments'] )
data_Frame['bonus_total_payments_rate']                 = data_Frame['bonus'].div( data_Frame['total_payments'] )
data_Frame['exer_stock_options_total_payments_rate']    = data_Frame['exercised_stock_options'].div( data_Frame['total_payments'] )

# Add email features
data_Frame['toPOI_rate']                                = data_Frame['from_this_person_to_poi'].div(data_Frame['from_messages'])
data_Frame['fromPOI_rate']                              = data_Frame['from_poi_to_this_person'].div(data_Frame['to_messages'])

# %%
# Create feature list
payment_features = ['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments', 'other', 'expenses', 'director_fees', 'total_payments']
stock_features   = ['exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value']
mail_features    = ['from_this_person_to_poi', 'from_poi_to_this_person', 'shared_receipt_with_poi']
extra_features = ['bonus_deferral_payments_rate', 'rest_stock_deferral_payments_rate', 'exer_stock_options_deferral_payments_rate',
                  'long_term_incentive_total_payments_rate', 'bonus_total_payments_rate', 'exer_stock_options_total_payments_rate',
                  'toPOI_rate', 'fromPOI_rate']

feature_list = ['poi'] + payment_features + stock_features + mail_features + extra_features

# Create data frame containing all features to be used
data_Frame = data_Frame[ feature_list ]

# %%
data_Frame.describe().transpose()
# Out:
#                                            count          mean           std  \
# poi                                        144.0  1.250000e-01  3.318733e-01
# salary                                      94.0  2.840875e+05  1.771311e+05
# bonus                                       81.0  1.201773e+06  1.441679e+06
# long_term_incentive                         65.0  7.464912e+05  8.629174e+05
# deferred_income                             49.0 -5.712835e+05  9.347149e+05
# deferral_payments                           37.0  8.671188e+05  1.297344e+06
# other                                       90.0  4.700610e+05  1.404768e+06
# expenses                                    96.0  5.453331e+04  4.671275e+04
# director_fees                               15.0  9.323447e+04  3.332008e+04
# total_payments                             123.0  2.516459e+06  9.455875e+06
# exercised_stock_options                    100.0  3.117640e+06  5.657924e+06
# restricted_stock                           110.0  1.184748e+06  2.217008e+06
# restricted_stock_deferred                   17.0 -4.456934e+05  6.934388e+05
# total_stock_value                          125.0  3.476076e+06  6.614499e+06
# from_this_person_to_poi                     86.0  3.933721e+01  9.912554e+01
# from_poi_to_this_person                     86.0  6.482558e+01  8.700104e+01
# shared_receipt_with_poi                     86.0  1.178297e+03  1.177507e+03
# bonus_deferral_payments_rate                21.0  5.632852e+00  1.140892e+01
# rest_stock_deferral_payments_rate           26.0  6.755963e+00  1.523531e+01
# exer_stock_options_deferral_payments_rate   32.0  1.144560e+02  5.292617e+02
# long_term_incentive_total_payments_rate     65.0  4.194093e-01  7.681837e-01
# bonus_total_payments_rate                   81.0  6.062845e-01  6.657780e-01
# exer_stock_options_total_payments_rate      85.0  9.186640e+00  3.907002e+01
# toPOI_rate                                  86.0  1.861860e-01  2.097734e-01
# fromPOI_rate                                86.0  3.819556e-02  4.043292e-02
#
#                                                     min            25%  \
# poi                                        0.000000e+00       0.000000
# salary                                     4.770000e+02  211802.000000
# bonus                                      7.000000e+04  425000.000000
# long_term_incentive                        6.922300e+04  275000.000000
# deferred_income                           -3.504386e+06 -583325.000000
# deferral_payments                          7.961000e+03   85430.000000
# other                                      2.000000e+00    1197.000000
# expenses                                   1.480000e+02   22140.500000
# director_fees                              1.750000e+04  100017.000000
# total_payments                             1.480000e+02  377387.500000
# exercised_stock_options                    9.803000e+03  570128.750000
# restricted_stock                           3.246000e+04  254018.000000
# restricted_stock_deferred                 -2.604490e+06 -409554.000000
# total_stock_value                          2.879800e+04  495633.000000
# from_this_person_to_poi                    0.000000e+00       1.000000
# from_poi_to_this_person                    0.000000e+00      10.000000
# shared_receipt_with_poi                    2.000000e+00     249.750000
# bonus_deferral_payments_rate               3.111877e-01       0.549472
# rest_stock_deferral_payments_rate          4.391618e-02       0.384428
# exer_stock_options_deferral_payments_rate  2.670067e-01       1.393650
# long_term_incentive_total_payments_rate    3.325158e-02       0.171672
# bonus_total_payments_rate                  6.759380e-02       0.352819
# exer_stock_options_total_payments_rate     1.437804e-02       0.385676
# toPOI_rate                                 0.000000e+00       0.015985
# fromPOI_rate                               0.000000e+00       0.010187
#
#                                                     50%           75%  \
# poi                                        0.000000e+00  0.000000e+00
# salary                                     2.587410e+05  3.086065e+05
# bonus                                      7.500000e+05  1.200000e+06
# long_term_incentive                        4.221580e+05  8.318090e+05
# deferred_income                           -1.440620e+05 -3.834600e+04
# deferral_payments                          2.274490e+05  8.753070e+05
# other                                      3.857000e+04  3.440270e+05
# expenses                                   4.654750e+04  7.925225e+04
# director_fees                              1.037500e+05  1.108950e+05
# total_payments                             1.099100e+06  2.064694e+06
# exercised_stock_options                    1.310814e+06  2.544450e+06
# restricted_stock                           4.517400e+05  1.002370e+06
# restricted_stock_deferred                 -1.536860e+05 -8.278200e+04
# total_stock_value                          1.110705e+06  3.064208e+06
# from_this_person_to_poi                    8.000000e+00  2.375000e+01
# from_poi_to_this_person                    3.500000e+01  7.225000e+01
# shared_receipt_with_poi                    7.412500e+02  1.888250e+03
# bonus_deferral_payments_rate               1.454847e+00  3.200529e+00
# rest_stock_deferral_payments_rate          8.949175e-01  3.174859e+00
# exer_stock_options_deferral_payments_rate  2.326517e+00  1.286587e+01
# long_term_incentive_total_payments_rate    2.677799e-01  3.932666e-01
# bonus_total_payments_rate                  4.924932e-01  6.413581e-01
# exer_stock_options_total_payments_rate     8.745775e-01  2.911465e+00
# toPOI_rate                                 1.167403e-01  2.720395e-01
# fromPOI_rate                               2.699567e-02  5.608871e-02
#
#                                                     max
# poi                                        1.000000e+00
# salary                                     1.111258e+06
# bonus                                      8.000000e+06
# long_term_incentive                        5.145434e+06
# deferred_income                           -8.330000e+02
# deferral_payments                          6.426990e+06
# other                                      1.035973e+07
# expenses                                   2.287630e+05
# director_fees                              1.250340e+05
# total_payments                             1.035598e+08
# exercised_stock_options                    3.434838e+07
# restricted_stock                           1.476169e+07
# restricted_stock_deferred                 -3.246000e+04
# total_stock_value                          4.911008e+07
# from_this_person_to_poi                    6.090000e+02
# from_poi_to_this_person                    5.280000e+02
# shared_receipt_with_poi                    5.521000e+03
# bonus_deferral_payments_rate               4.346251e+01
# rest_stock_deferral_payments_rate          7.274960e+01
# exer_stock_options_deferral_payments_rate  2.998934e+03
# long_term_incentive_total_payments_rate    5.601357e+00
# bonus_total_payments_rate                  5.196029e+00
# exer_stock_options_total_payments_rate     3.377434e+02
# toPOI_rate                                 1.000000e+00
# fromPOI_rate                               2.173410e-01

# %%
crt_plot(data_Frame, data_Frame.columns, shape=(5,5), log=log_list, sort=False, save=IMAGES+"all_features_box_plots")

# %%
data_Frame[ data_Frame['exer_stock_options_deferral_payments_rate'] > 100 ]
# Out:
#                  poi     salary      bonus  long_term_incentive  \
# HIRKO JOSEPH       1        NaN        NaN                  NaN
# LAY KENNETH L      1  1072321.0  7000000.0            3600000.0
# THORN TERENCE H    0   222093.0        NaN             200000.0
#
#                  deferred_income  deferral_payments       other  expenses  \
# HIRKO JOSEPH                 NaN            10259.0      2856.0   77978.0
# LAY KENNETH L          -300000.0           202911.0  10359729.0   99832.0
# THORN TERENCE H              NaN            16586.0    426629.0   46145.0
#
#                  director_fees  total_payments  ...  from_poi_to_this_person  \
# HIRKO JOSEPH               NaN         91093.0  ...                      NaN
# LAY KENNETH L              NaN     103559793.0  ...                    123.0
# THORN TERENCE H            NaN        911453.0  ...                      0.0
#
#                  shared_receipt_with_poi  bonus_deferral_payments_rate  \
# HIRKO JOSEPH                         NaN                           NaN
# LAY KENNETH L                     2411.0                     34.497883
# THORN TERENCE H                     73.0                           NaN
#
#                  rest_stock_deferral_payments_rate  \
# HIRKO JOSEPH                                   NaN
# LAY KENNETH L                            72.749600
# THORN TERENCE H                          22.025805
#
#                  exer_stock_options_deferral_payments_rate  \
# HIRKO JOSEPH                                   2998.934009
# LAY KENNETH L                                   169.278078
# THORN TERENCE H                                 268.447848
#
#                  long_term_incentive_total_payments_rate  \
# HIRKO JOSEPH                                         NaN
# LAY KENNETH L                                   0.034763
# THORN TERENCE H                                 0.219430
#
#                  bonus_total_payments_rate  \
# HIRKO JOSEPH                           NaN
# LAY KENNETH L                     0.067594
# THORN TERENCE H                        NaN
#
#                  exer_stock_options_total_payments_rate  toPOI_rate  \
# HIRKO JOSEPH                                 337.743449         NaN
# LAY KENNETH L                                  0.331677    0.444444
# THORN TERENCE H                                4.885031    0.000000
#
#                  fromPOI_rate
# HIRKO JOSEPH              NaN
# LAY KENNETH L        0.028785
# THORN TERENCE H      0.000000
#
# [3 rows x 27 columns]

# %%
data_Frame[ data_Frame['bonus_total_payments_rate'] > 1 ]
# Out:
#                      poi    salary      bonus  long_term_incentive  \
# DERRICK JR. JAMES V    0  492375.0   800000.0             484000.0
# ELLIOTT STEVEN         0  170941.0   350000.0                  NaN
# HANNON KEVIN P         1  243293.0  1500000.0            1617011.0
# RICE KENNETH D         1  420636.0  1750000.0            1617011.0
#
#                      deferred_income  deferral_payments     other  expenses  \
# DERRICK JR. JAMES V       -1284000.0                NaN    7482.0   51124.0
# ELLIOTT STEVEN             -400729.0                NaN   12961.0   78552.0
# HANNON KEVIN P            -3117011.0                NaN   11350.0   34039.0
# RICE KENNETH D            -3504386.0                NaN  174839.0   46950.0
#
#                      director_fees  total_payments  ...  \
# DERRICK JR. JAMES V            NaN        550981.0  ...
# ELLIOTT STEVEN                 NaN        211725.0  ...
# HANNON KEVIN P                 NaN        288682.0  ...
# RICE KENNETH D                 NaN        505050.0  ...
#
#                      from_poi_to_this_person  shared_receipt_with_poi  \
# DERRICK JR. JAMES V                     64.0                   1401.0
# ELLIOTT STEVEN                           NaN                      NaN
# HANNON KEVIN P                          32.0                   1035.0
# RICE KENNETH D                          42.0                    864.0
#
#                      bonus_deferral_payments_rate  \
# DERRICK JR. JAMES V                           NaN
# ELLIOTT STEVEN                                NaN
# HANNON KEVIN P                                NaN
# RICE KENNETH D                                NaN
#
#                      rest_stock_deferral_payments_rate  \
# DERRICK JR. JAMES V                                NaN
# ELLIOTT STEVEN                                     NaN
# HANNON KEVIN P                                     NaN
# RICE KENNETH D                                     NaN
#
#                      exer_stock_options_deferral_payments_rate  \
# DERRICK JR. JAMES V                                        NaN
# ELLIOTT STEVEN                                             NaN
# HANNON KEVIN P                                             NaN
# RICE KENNETH D                                             NaN
#
#                      long_term_incentive_total_payments_rate  \
# DERRICK JR. JAMES V                                 0.878433
# ELLIOTT STEVEN                                           NaN
# HANNON KEVIN P                                      5.601357
# RICE KENNETH D                                      3.201685
#
#                      bonus_total_payments_rate  \
# DERRICK JR. JAMES V                   1.451956
# ELLIOTT STEVEN                        1.653088
# HANNON KEVIN P                        5.196029
# RICE KENNETH D                        3.465003
#
#                      exer_stock_options_total_payments_rate  toPOI_rate  \
# DERRICK JR. JAMES V                               16.029433    0.022002
# ELLIOTT STEVEN                                    23.097622         NaN
# HANNON KEVIN P                                    19.183742    0.656250
# RICE KENNETH D                                    39.192506    0.222222
#
#                      fromPOI_rate
# DERRICK JR. JAMES V      0.029344
# ELLIOTT STEVEN                NaN
# HANNON KEVIN P           0.030622
# RICE KENNETH D           0.046409
#
# [4 rows x 27 columns]

# %%
data_Frame.to_pickle(DATA+'my_dataFrame.pkl')

# %%
### Store to my_dataset for easy export below.
my_dataset = data_dict

# %%
### Extract features and labels from dataset for local testing
data = featureFormat(my_dataset, features_list, sort_keys = True)
labels, features = targetFeatureSplit(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-4dffd7a755dc> in <module>()
#       1 ### Extract features and labels from dataset for local testing
# ----> 2 data = featureFormat(my_dataset, features_list, sort_keys = True)
#       3 labels, features = targetFeatureSplit(data)
#
# NameError: name 'features_list' is not defined

# %%
### Task 4: Try a varity of classifiers
### Please name your classifier clf for easy export below.
### Note that if you want to do PCA or other multi-stage operations,
### you'll need to use Pipelines. For more info:
### http://scikit-learn.org/stable/modules/pipeline.html

# %%
# Provided to give you a starting point. Try a variety of classifiers.
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()

# %%
### Task 5: Tune your classifier to achieve better than .3 precision and recall 
### using our testing script. Check the tester.py script in the final project
### folder for details on the evaluation method, especially the test_classifier
### function. Because of the small size of the dataset, the script uses
### stratified shuffle split cross validation. For more info: 
### http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.StratifiedShuffleSplit.html

# Example starting point. Try investigating other evaluation techniques!
from sklearn.cross_validation import train_test_split
features_train, features_test, labels_train, labels_test = \
    train_test_split(features, labels, test_size=0.3, random_state=42)

# %%
### Task 6: Dump your classifier, dataset, and features_list so anyone can
### check your results. You do not need to change anything below, but make sure
### that the version of poi_id.py that you submit can be run on its own and
### generates the necessary .pkl files for validating your results.

dump_classifier_and_data(clf, my_dataset, features_list)
